# %% [markdown]
# ## Exploratory Data Analysis on Craiglist Housing Data in New York and San Francisco:

# %% [markdown]
# ### 1. Loading in the packages and reading data in from the database:

# %%
import os
import pandas as pd
import numpy as np
from craigslist import CraigslistHousing #this is a modified version that extracts more info
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sqlite3

sns.set_style("darkgrid", {"axes.facecolor": ".95"})

matplotlib.rcParams['figure.figsize'] = (17.0, 12.0)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import sys
sys.path.insert(0, '/Users/alexpapiu/Documents/Craiglist_Project')
import cl_pipeline

# %%
os.chdir("/Users/alexpapiu/Documents/Data/Craigslist")
conn = sqlite3.connect("housing.db")
data = pd.read_sql_query("select * from cl_housing", con = conn).drop_duplicates()

# %%
data.head()
# Out:
#            id          datetime geotag  has_image  has_map          id.1  \
# 0  5774898506  2016-09-10 04:06   None          0        0  5.774899e+09
# 1  5774903240  2016-09-10 03:58   None          0        0  5.774903e+09
# 2  5774900841  2016-09-10 03:54   None          0        0  5.774901e+09
# 3  5774904496  2016-09-10 03:37   None          0        0  5.774904e+09
# 4  5774901867  2016-09-10 03:33   None          0        0  5.774902e+09
#
#                                                 name  num_bed  price  sq_feet  \
# 0          Very large apt Stunning ?Luxury 3 Bedroom      3.0  $1670      NaN
# 1  Super Awesome two br ?Heat Incl apartment for ...      NaN  $1182      NaN
# 2  ? looking for roommate :) sunny new apt in wil...      3.0  $1400      NaN
# 3      VERY AFFORDABLE?  ROOM/APT. READY TO MOVE IN!      3.0  $1600      NaN
# 4   stunning two bedroom? ? wood floors wood kitchen      2.0  $1176      NaN
#
#                                                  url             where  \
# 0  http://newyork.craigslist.org/brk/abo/57748985...         ?Flatbush
# 1  http://newyork.craigslist.org/brk/abo/57749032...     ?Williamsburg
# 2  http://newyork.craigslist.org/brk/abo/57749008...    ? Williamsburg
# 3  http://newyork.craigslist.org/brk/abo/57749044...        ? New York
# 4  http://newyork.craigslist.org/brk/abo/57749018...  ? Clinton Hills?
#
#          area
# 0  newyorkbrk
# 1  newyorkbrk
# 2  newyorkbrk
# 3  newyorkbrk
# 4  newyorkbrk

# %%
data["area"].unique()
# Out:
# array(['newyorkbrk', 'newyorkmnh', 'sfbaysfc'], dtype=object)

# %%
data["where"].value_counts()
# Out:
# Upper East Side                             3581
# SOMA / south beach                          2248
# Bushwick                                    2029
# Upper West Side                             1458
# East Village                                1438
# Murray Hill                                 1319
# Midtown West                                1213
# Williamsburg                                1155
# Midtown East                                 995
# pacific heights                              970
# nob hill                                     901
# lower nob hill                               876
# Crown Heights                                801
# mission district                             746
# East Harlem                                  740
# Harlem / Morningside                         727
# marina / cow hollow                          717
# West Village                                 688
# Chelsea                                      682
# Inwood / Wash Hts                            679
# downtown / civic / van ness                  646
# russian hill                                 577
# richmond / seacliff                          569
# Bedstuy                                      551
# lower pac hts                                543
# noe valley                                   539
# sunset / parkside                            517
# potrero hill                                 497
# hayes valley                                 491
# ingleside / SFSU / CCSF                      468
#                                             ...
# BOERUM HILL / NO FEE                           1
# ❖ Prospect                                     1
# ✿Greenwood Heights✿                            1
# Ainslie St & Keap - Williamsburg               1
# Flatbush-Dimas Park                            1
# Bedford L Williamsburg                         1
# Ditmas Park.                                   1
# 2918 Sloat                                     1
# Richmond District                              1
# BUSHWICK @ J M Z MYRTLE BROADWAY STOP___       1
# Bedford Stuyvesant   Bedstuy                   1
# ♢Greenpoint♢                                   1
# E. 50s & Ave. K                                1
# Bushwick@MorganL/Jefferson L                   1
# 1850                                           1
# *Bushwick*Loft*Bushwick                        1
# carroll gardens                                1
# ⇘ Crown Heights/ Lefferts Gardens              1
# Graham Av - L train                            1
# bed stuy                                       1
# WILLIAMSBURG/LORIMER                           1
# ☼ Crown Heights                                1
# bEDSTUY -j,z@GATES                             1
# ⇗ Kips Bay⇗                                    1
# Leffert Gardens                                1
# ♢ flatbush                                     1
# L Train Jefferson St * M Central * J M Z       1
# Greenpoint / green point / No Fee              1
# Williamsburg Greenpoint Eckford st             1
# Flatbush Avenue                                1
# Name: where, dtype: int64

# %%
data.dtypes
# Out:
# id             int64
# datetime      object
# geotag        object
# has_image      int64
# has_map        int64
# id.1         float64
# name          object
# num_bed      float64
# price         object
# sq_feet      float64
# url           object
# where         object
# area          object
# dtype: object

# %% [markdown]
# ### Cleaning Data:

# %%
data = cl_pipeline.clean_data(data)

# %%
data["where"] = (data["where"].str.replace(r"[^\w\s-]", " ")
                              .str.replace(" +", " ")
                              .str.strip())

# %%
data.head()
# Out:
#            id            datetime geotag  has_image  has_map  \
# 0  5774898506 2016-09-10 04:06:00   None          0        0
# 1  5774903240 2016-09-10 03:58:00   None          0        0
# 2  5774900841 2016-09-10 03:54:00   None          0        0
# 3  5774904496 2016-09-10 03:37:00   None          0        0
# 4  5774901867 2016-09-10 03:33:00   None          0        0
#
#                                                 name num_bed   price  sq_feet  \
# 0          very large apt stunning ?luxury 3 bedroom       3  1670.0      NaN
# 1  super awesome two br ?heat incl apartment for ...     NaN  1182.0      NaN
# 2  ? looking for roommate :) sunny new apt in wil...       3  1400.0      NaN
# 3      very affordable?  room apt. ready to move in!       3  1600.0      NaN
# 4   stunning two bedroom? ? wood floors wood kitchen       2  1176.0      NaN
#
#                                                  url          where      area  \
# 0  http://newyork.craigslist.org/brk/abo/57748985...       flatbush  Brooklyn
# 1  http://newyork.craigslist.org/brk/abo/57749032...   williamsburg  Brooklyn
# 2  http://newyork.craigslist.org/brk/abo/57749008...   williamsburg  Brooklyn
# 3  http://newyork.craigslist.org/brk/abo/57749044...       new york  Brooklyn
# 4  http://newyork.craigslist.org/brk/abo/57749018...  clinton hills  Brooklyn
#
#    dayofweek  hour  int_bed  per_person
# 0          5     4      3.0  556.666667
# 1          5     3      NaN         NaN
# 2          5     3      3.0  466.666667
# 3          5     3      3.0  533.333333
# 4          5     3      2.0  588.000000

# %%
data.dtypes
# Out:
# id                     int64
# datetime      datetime64[ns]
# geotag                object
# has_image              int64
# has_map                int64
# name                  object
# num_bed               object
# price                float64
# sq_feet              float64
# url                   object
# where                 object
# area                  object
# dayofweek              int64
# hour                   int64
# int_bed              float64
# per_person           float64
# dtype: object

# %%
data.shape
# Out:
# (57252, 16)

# %%
data.to_sql("cl_housing_clean", conn, index = False, if_exists="replace")

# %%
data_nonna = data.dropna(0, subset = ["where"])

# %%
data_ditmas = data_nonna[data_nonna["where"].str.contains("ditmas")]

# %%
data_ditmas
# Out:
# (205, 16)

# %%
(data_ditmas[data_ditmas["num_bed"].isin([1, 2, 3])].query("per_person < 5000")[["num_bed", "per_person"]]
     .pivot(columns = "num_bed", values = "per_person")
     .plot.hist(alpha = 0.75, bins = 30, stacked = True))

plt.title("Rent per Bedroom in Listings contaning 'ditmas'")

# %% [markdown]
# ## Exploratory Data Analysis:

# %% [markdown]
# ### What are the neighborhoods with the most listings?

# %%
data["where"].value_counts()[:15].plot(kind = "barh")

# %% [markdown]
# ### Median Rent per Bedroom:

# %%
sns.barplot(x = "area", y = "per_person", data = data, estimator = np.median)

# %% [markdown]
# ### Median Rent for one Bedroom:

# %%
sns.barplot(x = "area", y = "per_person", data = data[data.int_bed == 1], estimator = np.median)

# %% [markdown]
# ### Median Rent Per Person by Number of Bedrooms:

# %%
sns.barplot(x = "num_bed", y = "per_person", data = data, estimator = np.mean, n_boot = 1000,
           order = ["Studio", 1, 2, 3, 4, 5, 6, 7, 8])

# %%
data.groupby(["num_bed", "area"])["num_bed"].count()
# Out:
# num_bed  area
# 1.0      Brooklyn         3794
#          Manhattan        5529
#          San Francisco    5888
# 2.0      Brooklyn         7758
#          Manhattan        4779
#          San Francisco    5337
# 3.0      Brooklyn         6566
#          Manhattan        2991
#          San Francisco    2017
# 4.0      Brooklyn         2137
#          Manhattan        1245
#          San Francisco     587
# 5.0      Brooklyn          316
#          Manhattan         463
#          San Francisco     183
# 6.0      Brooklyn           40
#          Manhattan          33
#          San Francisco      40
# 7.0      Brooklyn           41
#          Manhattan           4
#          San Francisco       7
# 8.0      Brooklyn            2
#          Manhattan           1
#          San Francisco      18
# Studio   Brooklyn          834
#          Manhattan        2196
#          San Francisco    2004
# Name: num_bed, dtype: int64

# %% [markdown]
# Hmm why does a 5 bedroom cost more than a 4 bedrooom per person?

# %% [markdown]
# ### Histogram of Rent Per Person:

# %%
data.query("per_person < 8000").hist("per_person", bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114749a58>]], dtype=object)

# %%
#data.query("per_person < 8000").hist("per_person", bins = 30, by = "area")

# %% [markdown]
# ### Histogram of Rent Per Person by City:

# %%
(data[data["num_bed"].isin([1, 2, 3])].query("per_person < 5000")[["num_bed", "per_person"]]
     .pivot(columns = "num_bed", values = "per_person")
     .plot.hist(alpha = 0.75, bins = 30, stacked = True))

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 5.0)

g = (data.query("per_person < 5000")[["area", "per_person"]]
     .pivot(columns = "area", values = "per_person")
     .plot.hist(alpha = 0.75, bins = 30, stacked = False, by = "area"))

plt.title("Rent per Bedroom in NYC vs. SF")

# %% [markdown]
# So if you want something under 1200 Brooklyn is probably your best best.

# %% [markdown]
# ### How does Square Footage come into play?

# %%
g = sns.lmplot(x = "sq_feet", y = "price",
           data=data.query("sq_feet < 4000 & price < 15000"),
           col = "area", fit_reg=True)


plt.subplots_adjust(top=0.9)
g.fig.suptitle('Rent versus Square Footage')

# %% [markdown]
# ### Rent by Area:

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

price_by_locations = (data.groupby("where")["per_person"]
                          .aggregate(["median", "count"])
                          .query("count > 500")
                          .sort_values("median"))
price_by_locations["median"].plot.barh(title = "Median Rent per Bedroom by Area")

# %% [markdown]
# ### For a 2 bedroom?

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

price_by_locations = (data.query("int_bed == 2").groupby("where")["per_person"]
                          .aggregate(["median", "count"])
                          .query("count > 100")
                          .sort_values("median"))
price_by_locations["median"].plot.barh(title = "Median Rent per Bedroom by Area")
